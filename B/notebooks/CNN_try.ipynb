# %% [markdown]
# # CNN for Particle Classification
#
# In this notebook, we train 10 layers deep CNN for particle type classification ($e^-$, $\mu^-$, and $\gamma$) using the workshop dataset.

# %%
from __future__ import print_function
from IPython.display import display
import torch, time
import numpy as np

# %%
from models import densenet
# Out:
# importing densenet

# %%
help(densenet.DenseNet)
# Out:
# Help on class DenseNet in module models.densenet:
#
# class DenseNet(torch.nn.modules.module.Module)
#  |  Densenet-BC model class, based on
#  |  `"Densely Connected Convolutional Networks" <https://arxiv.org/pdf/1608.06993.pdf>`_
#  |
#  |  Args:
#  |      growth_rate (int) - how many filters to add each layer (`k` in paper)
#  |      block_config (list of 4 ints) - how many layers in each pooling block
#  |      num_init_features (int) - the number of filters to learn in the first convolution layer
#  |      bn_size (int) - multiplicative factor for number of bottle neck layers
#  |        (i.e. bn_size * k features in the bottleneck layer)
#  |      drop_rate (float) - dropout rate after each dense layer
#  |      num_classes (int) - number of classification classes
#  |
#  |  Method resolution order:
#  |      DenseNet
#  |      torch.nn.modules.module.Module
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, growth_rate=32, block_config=(6, 12, 24, 16), num_init_features=64, bn_size=4, drop_rate=0, num_classes=1000)
#  |
#  |  forward(self, x)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from torch.nn.modules.module.Module:
#  |
#  |  __call__(self, *input, **kwargs)
#  |
#  |  __delattr__(self, name)
#  |
#  |  __dir__(self)
#  |
#  |  __getattr__(self, name)
#  |
#  |  __repr__(self)
#  |
#  |  __setattr__(self, name, value)
#  |
#  |  __setstate__(self, state)
#  |
#  |  add_module(self, name, module)
#  |      Adds a child module to the current module.
#  |
#  |      The module can be accessed as an attribute using the given name.
#  |
#  |      Args:
#  |          name (string): name of the child module. The child module can be
#  |              accessed from this module using the given name
#  |          parameter (Module): child module to be added to the module.
#  |
#  |  apply(self, fn)
#  |      Applies ``fn`` recursively to every submodule (as returned by ``.children()``)
#  |      as well as self. Typical use includes initializing the parameters of a model
#  |      (see also :ref:`torch-nn-init`).
#  |
#  |      Args:
#  |          fn (:class:`Module` -> None): function to be applied to each submodule
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |      Example::
#  |
#  |          >>> def init_weights(m):
#  |                  print(m)
#  |                  if type(m) == nn.Linear:
#  |                      m.weight.data.fill_(1.0)
#  |                      print(m.weight)
#  |
#  |          >>> net = nn.Sequential(nn.Linear(2, 2), nn.Linear(2, 2))
#  |          >>> net.apply(init_weights)
#  |          Linear(in_features=2, out_features=2, bias=True)
#  |          Parameter containing:
#  |          tensor([[ 1.,  1.],
#  |                  [ 1.,  1.]])
#  |          Linear(in_features=2, out_features=2, bias=True)
#  |          Parameter containing:
#  |          tensor([[ 1.,  1.],
#  |                  [ 1.,  1.]])
#  |          Sequential(
#  |            (0): Linear(in_features=2, out_features=2, bias=True)
#  |            (1): Linear(in_features=2, out_features=2, bias=True)
#  |          )
#  |          Sequential(
#  |            (0): Linear(in_features=2, out_features=2, bias=True)
#  |            (1): Linear(in_features=2, out_features=2, bias=True)
#  |          )
#  |
#  |  buffers(self, recurse=True)
#  |      Returns an iterator over module buffers.
#  |
#  |      Args:
#  |          recurse (bool): if True, then yields buffers of this module
#  |              and all submodules. Otherwise, yields only buffers that
#  |              are direct members of this module.
#  |
#  |      Yields:
#  |          torch.Tensor: module buffer
#  |
#  |      Example::
#  |
#  |          >>> for buf in model.buffers():
#  |          >>>     print(type(buf.data), buf.size())
#  |          <class 'torch.FloatTensor'> (20L,)
#  |          <class 'torch.FloatTensor'> (20L, 1L, 5L, 5L)
#  |
#  |  children(self)
#  |      Returns an iterator over immediate children modules.
#  |
#  |      Yields:
#  |          Module: a child module
#  |
#  |  cpu(self)
#  |      Moves all model parameters and buffers to the CPU.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  cuda(self, device=None)
#  |      Moves all model parameters and buffers to the GPU.
#  |
#  |      This also makes associated parameters and buffers different objects. So
#  |      it should be called before constructing optimizer if the module will
#  |      live on GPU while being optimized.
#  |
#  |      Arguments:
#  |          device (int, optional): if specified, all parameters will be
#  |              copied to that device
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  double(self)
#  |      Casts all floating point parameters and buffers to ``double`` datatype.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  eval(self)
#  |      Sets the module in evaluation mode.
#  |
#  |      This has any effect only on certain modules. See documentations of
#  |      particular modules for details of their behaviors in training/evaluation
#  |      mode, if they are affected, e.g. :class:`Dropout`, :class:`BatchNorm`,
#  |      etc.
#  |
#  |  extra_repr(self)
#  |      Set the extra representation of the module
#  |
#  |      To print customized extra information, you should reimplement
#  |      this method in your own modules. Both single-line and multi-line
#  |      strings are acceptable.
#  |
#  |  float(self)
#  |      Casts all floating point parameters and buffers to float datatype.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  half(self)
#  |      Casts all floating point parameters and buffers to ``half`` datatype.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  load_state_dict(self, state_dict, strict=True)
#  |      Copies parameters and buffers from :attr:`state_dict` into
#  |      this module and its descendants. If :attr:`strict` is ``True``, then
#  |      the keys of :attr:`state_dict` must exactly match the keys returned
#  |      by this module's :meth:`~torch.nn.Module.state_dict` function.
#  |
#  |      Arguments:
#  |          state_dict (dict): a dict containing parameters and
#  |              persistent buffers.
#  |          strict (bool, optional): whether to strictly enforce that the keys
#  |              in :attr:`state_dict` match the keys returned by this module's
#  |              :meth:`~torch.nn.Module.state_dict` function. Default: ``True``
#  |
#  |  modules(self)
#  |      Returns an iterator over all modules in the network.
#  |
#  |      Yields:
#  |          Module: a module in the network
#  |
#  |      Note:
#  |          Duplicate modules are returned only once. In the following
#  |          example, ``l`` will be returned only once.
#  |
#  |      Example::
#  |
#  |          >>> l = nn.Linear(2, 2)
#  |          >>> net = nn.Sequential(l, l)
#  |          >>> for idx, m in enumerate(net.modules()):
#  |                  print(idx, '->', m)
#  |
#  |          0 -> Sequential (
#  |            (0): Linear (2 -> 2)
#  |            (1): Linear (2 -> 2)
#  |          )
#  |          1 -> Linear (2 -> 2)
#  |
#  |  named_buffers(self, prefix='', recurse=True)
#  |      Returns an iterator over module buffers, yielding both the
#  |      name of the buffer as well as the buffer itself.
#  |
#  |      Args:
#  |          prefix (str): prefix to prepend to all buffer names.
#  |          recurse (bool): if True, then yields buffers of this module
#  |              and all submodules. Otherwise, yields only buffers that
#  |              are direct members of this module.
#  |
#  |      Yields:
#  |          (string, torch.Tensor): Tuple containing the name and buffer
#  |
#  |      Example::
#  |
#  |          >>> for name, buf in self.named_buffers():
#  |          >>>    if name in ['running_var']:
#  |          >>>        print(buf.size())
#  |
#  |  named_children(self)
#  |      Returns an iterator over immediate children modules, yielding both
#  |      the name of the module as well as the module itself.
#  |
#  |      Yields:
#  |          (string, Module): Tuple containing a name and child module
#  |
#  |      Example::
#  |
#  |          >>> for name, module in model.named_children():
#  |          >>>     if name in ['conv4', 'conv5']:
#  |          >>>         print(module)
#  |
#  |  named_modules(self, memo=None, prefix='')
#  |      Returns an iterator over all modules in the network, yielding
#  |      both the name of the module as well as the module itself.
#  |
#  |      Yields:
#  |          (string, Module): Tuple of name and module
#  |
#  |      Note:
#  |          Duplicate modules are returned only once. In the following
#  |          example, ``l`` will be returned only once.
#  |
#  |      Example::
#  |
#  |          >>> l = nn.Linear(2, 2)
#  |          >>> net = nn.Sequential(l, l)
#  |          >>> for idx, m in enumerate(net.named_modules()):
#  |                  print(idx, '->', m)
#  |
#  |          0 -> ('', Sequential (
#  |            (0): Linear (2 -> 2)
#  |            (1): Linear (2 -> 2)
#  |          ))
#  |          1 -> ('0', Linear (2 -> 2))
#  |
#  |  named_parameters(self, prefix='', recurse=True)
#  |      Returns an iterator over module parameters, yielding both the
#  |      name of the parameter as well as the parameter itself.
#  |
#  |      Args:
#  |          prefix (str): prefix to prepend to all parameter names.
#  |          recurse (bool): if True, then yields parameters of this module
#  |              and all submodules. Otherwise, yields only parameters that
#  |              are direct members of this module.
#  |
#  |      Yields:
#  |          (string, Parameter): Tuple containing the name and parameter
#  |
#  |      Example::
#  |
#  |          >>> for name, param in self.named_parameters():
#  |          >>>    if name in ['bias']:
#  |          >>>        print(param.size())
#  |
#  |  parameters(self, recurse=True)
#  |      Returns an iterator over module parameters.
#  |
#  |      This is typically passed to an optimizer.
#  |
#  |      Args:
#  |          recurse (bool): if True, then yields parameters of this module
#  |              and all submodules. Otherwise, yields only parameters that
#  |              are direct members of this module.
#  |
#  |      Yields:
#  |          Parameter: module parameter
#  |
#  |      Example::
#  |
#  |          >>> for param in model.parameters():
#  |          >>>     print(type(param.data), param.size())
#  |          <class 'torch.FloatTensor'> (20L,)
#  |          <class 'torch.FloatTensor'> (20L, 1L, 5L, 5L)
#  |
#  |  register_backward_hook(self, hook)
#  |      Registers a backward hook on the module.
#  |
#  |      The hook will be called every time the gradients with respect to module
#  |      inputs are computed. The hook should have the following signature::
#  |
#  |          hook(module, grad_input, grad_output) -> Tensor or None
#  |
#  |      The :attr:`grad_input` and :attr:`grad_output` may be tuples if the
#  |      module has multiple inputs or outputs. The hook should not modify its
#  |      arguments, but it can optionally return a new gradient with respect to
#  |      input that will be used in place of :attr:`grad_input` in subsequent
#  |      computations.
#  |
#  |      Returns:
#  |          :class:`torch.utils.hooks.RemovableHandle`:
#  |              a handle that can be used to remove the added hook by calling
#  |              ``handle.remove()``
#  |
#  |      .. warning ::
#  |
#  |          The current implementation will not have the presented behavior
#  |          for complex :class:`Module` that perform many operations.
#  |          In some failure cases, :attr:`grad_input` and :attr:`grad_output` will only
#  |          contain the gradients for a subset of the inputs and outputs.
#  |          For such :class:`Module`, you should use :func:`torch.Tensor.register_hook`
#  |          directly on a specific input or output to get the required gradients.
#  |
#  |  register_buffer(self, name, tensor)
#  |      Adds a persistent buffer to the module.
#  |
#  |      This is typically used to register a buffer that should not to be
#  |      considered a model parameter. For example, BatchNorm's ``running_mean``
#  |      is not a parameter, but is part of the persistent state.
#  |
#  |      Buffers can be accessed as attributes using given names.
#  |
#  |      Args:
#  |          name (string): name of the buffer. The buffer can be accessed
#  |              from this module using the given name
#  |          tensor (Tensor): buffer to be registered.
#  |
#  |      Example::
#  |
#  |          >>> self.register_buffer('running_mean', torch.zeros(num_features))
#  |
#  |  register_forward_hook(self, hook)
#  |      Registers a forward hook on the module.
#  |
#  |      The hook will be called every time after :func:`forward` has computed an output.
#  |      It should have the following signature::
#  |
#  |          hook(module, input, output) -> None
#  |
#  |      The hook should not modify the input or output.
#  |
#  |      Returns:
#  |          :class:`torch.utils.hooks.RemovableHandle`:
#  |              a handle that can be used to remove the added hook by calling
#  |              ``handle.remove()``
#  |
#  |  register_forward_pre_hook(self, hook)
#  |      Registers a forward pre-hook on the module.
#  |
#  |      The hook will be called every time before :func:`forward` is invoked.
#  |      It should have the following signature::
#  |
#  |          hook(module, input) -> None
#  |
#  |      The hook should not modify the input.
#  |
#  |      Returns:
#  |          :class:`torch.utils.hooks.RemovableHandle`:
#  |              a handle that can be used to remove the added hook by calling
#  |              ``handle.remove()``
#  |
#  |  register_parameter(self, name, param)
#  |      Adds a parameter to the module.
#  |
#  |      The parameter can be accessed as an attribute using given name.
#  |
#  |      Args:
#  |          name (string): name of the parameter. The parameter can be accessed
#  |              from this module using the given name
#  |          parameter (Parameter): parameter to be added to the module.
#  |
#  |  share_memory(self)
#  |
#  |  state_dict(self, destination=None, prefix='', keep_vars=False)
#  |      Returns a dictionary containing a whole state of the module.
#  |
#  |      Both parameters and persistent buffers (e.g. running averages) are
#  |      included. Keys are corresponding parameter and buffer names.
#  |
#  |      Returns:
#  |          dict:
#  |              a dictionary containing a whole state of the module
#  |
#  |      Example::
#  |
#  |          >>> module.state_dict().keys()
#  |          ['bias', 'weight']
#  |
#  |  to(self, *args, **kwargs)
#  |      Moves and/or casts the parameters and buffers.
#  |
#  |      This can be called as
#  |
#  |      .. function:: to(device=None, dtype=None, non_blocking=False)
#  |
#  |      .. function:: to(dtype, non_blocking=False)
#  |
#  |      .. function:: to(tensor, non_blocking=False)
#  |
#  |      Its signature is similar to :meth:`torch.Tensor.to`, but only accepts
#  |      floating point desired :attr:`dtype` s. In addition, this method will
#  |      only cast the floating point parameters and buffers to :attr:`dtype`
#  |      (if given). The integral parameters and buffers will be moved
#  |      :attr:`device`, if that is given, but with dtypes unchanged. When
#  |      :attr:`non_blocking` is set, it tries to convert/move asynchronously
#  |      with respect to the host if possible, e.g., moving CPU Tensors with
#  |      pinned memory to CUDA devices.
#  |
#  |      See below for examples.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Args:
#  |          device (:class:`torch.device`): the desired device of the parameters
#  |              and buffers in this module
#  |          dtype (:class:`torch.dtype`): the desired floating point type of
#  |              the floating point parameters and buffers in this module
#  |          tensor (torch.Tensor): Tensor whose dtype and device are the desired
#  |              dtype and device for all parameters and buffers in this module
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |      Example::
#  |
#  |          >>> linear = nn.Linear(2, 2)
#  |          >>> linear.weight
#  |          Parameter containing:
#  |          tensor([[ 0.1913, -0.3420],
#  |                  [-0.5113, -0.2325]])
#  |          >>> linear.to(torch.double)
#  |          Linear(in_features=2, out_features=2, bias=True)
#  |          >>> linear.weight
#  |          Parameter containing:
#  |          tensor([[ 0.1913, -0.3420],
#  |                  [-0.5113, -0.2325]], dtype=torch.float64)
#  |          >>> gpu1 = torch.device("cuda:1")
#  |          >>> linear.to(gpu1, dtype=torch.half, non_blocking=True)
#  |          Linear(in_features=2, out_features=2, bias=True)
#  |          >>> linear.weight
#  |          Parameter containing:
#  |          tensor([[ 0.1914, -0.3420],
#  |                  [-0.5112, -0.2324]], dtype=torch.float16, device='cuda:1')
#  |          >>> cpu = torch.device("cpu")
#  |          >>> linear.to(cpu)
#  |          Linear(in_features=2, out_features=2, bias=True)
#  |          >>> linear.weight
#  |          Parameter containing:
#  |          tensor([[ 0.1914, -0.3420],
#  |                  [-0.5112, -0.2324]], dtype=torch.float16)
#  |
#  |  train(self, mode=True)
#  |      Sets the module in training mode.
#  |
#  |      This has any effect only on certain modules. See documentations of
#  |      particular modules for details of their behaviors in training/evaluation
#  |      mode, if they are affected, e.g. :class:`Dropout`, :class:`BatchNorm`,
#  |      etc.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  type(self, dst_type)
#  |      Casts all parameters and buffers to :attr:`dst_type`.
#  |
#  |      Arguments:
#  |          dst_type (type or string): the desired type
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  zero_grad(self)
#  |      Sets gradients of all model parameters to zero.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from torch.nn.modules.module.Module:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from torch.nn.modules.module.Module:
#  |
#  |  dump_patches = False

# %% [markdown]
# ## Defining a network
# Let's define our network. The design below consists of 7 convolution layers + 3 fully-connected layers (10 learnable layers). Here is a summary of the graph operations.
# * Feature extractor:
#     1. Input shape: (N,88,168,2) ... N samples of 88x168 2D images with 2 channels
#     2. Convolution layer + ReLU, 16 filters, kernel size 3x3, stride 1 (default)
#     3. 2D max-pooling, kernel size 2, stride 2
#     4. 2x Convolution layer + ReLU, 32 filters, kernel size 3x3, stride 1 (default)
#     5. 2D max-pooling, kernel size 2, stride 2
#     6. 2x Convolution layer + ReLU, 64 filters, kernel size 3x3, stride 1 (default)
#     7. 2D max-pooling, kernel size 2, stride 2
#     8. 2x Convolution layer + ReLU, 128 filters, kernel size 3x3, stride 1 (default)
# * Flattening
#     9. 2D average-pooling, kernel size = 2D image spatial dimension at this point (results in length 128 1D array)
# * Classifier:
#     10. Fully-connected layer + ReLU, 128 filters
#     11. Fully-connected layer + ReLU, 128 filters
#     12. Fully-connected layer, M filters where M = number of classification categories

# %% [markdown]
# class CNN(torch.nn.Module):
#
#     def __init__(self, num_class):
#
#         super(CNN, self).__init__()
#         # feature extractor CNN
#         self._feature = torch.nn.Sequential(
#             torch.nn.Conv2d(2,16,3), torch.nn.ReLU(),
#             torch.nn.MaxPool2d(2,2),
#             torch.nn.Conv2d(16,32,3), torch.nn.ReLU(),
#             torch.nn.Conv2d(32,32,3), torch.nn.ReLU(),
#             torch.nn.MaxPool2d(2,2),
#             torch.nn.Conv2d(32,64,3), torch.nn.ReLU(),
#             torch.nn.Conv2d(64,64,3), torch.nn.ReLU(),
#             torch.nn.MaxPool2d(2,2),
#             torch.nn.Conv2d(64,128,3), torch.nn.ReLU(),
#             torch.nn.Conv2d(128,128,3), torch.nn.ReLU())
#         self._classifier = torch.nn.Sequential(
#             torch.nn.Linear(128,128), torch.nn.ReLU(),
#             torch.nn.Linear(128,128), torch.nn.ReLU(),
#             torch.nn.Linear(128,num_class)
#         )
#
#     def forward(self, x):
#         net = self._feature(x)
#         net = torch.nn.AvgPool2d(net.size()[2:])(net)
#         return self._classifier(net.view(-1,128))

# %% [markdown]
# ## Defining a train loop
# For convenience, define a _BLOB_ class to keep objects together. To a BLOB instance, we attach LeNet, our loss function (`nn.CrossEntropyLoss`), and Adam optimizer algorithm. For analysis purpose, we also include `nn.Softmax`. Finally, we attach data and label place holders.

# %%
class BLOB:
    pass
blob=BLOB()
blob.net       = densenet.DenseNet(num_classes=3).cuda() #CNN(3).cuda() # construct Lenet for 3 class classification, use GPU
blob.criterion = torch.nn.CrossEntropyLoss() # use softmax loss to define an error
blob.optimizer = torch.optim.Adam(blob.net.parameters()) # use Adam optimizer algorithm
blob.softmax   = torch.nn.Softmax(dim=1) # not for training, but softmax score for each class
blob.data      = None # data for training/analysis
blob.label     = None # label for training/analysis

# %% [markdown]
# We define 2 functions to be called in the training loop: forward and backward. These functions implement the evaluation of the results, error (loss) definition, and propagation of errors (gradients) back to update the network parameters.

# %%
def forward(blob,train=True):
    """
       Args: blob should have attributes, net, criterion, softmax, data, label
       Returns: a dictionary of predicted labels, softmax, loss, and accuracy
    """
    with torch.set_grad_enabled(train):
        # Prediction
        data = torch.as_tensor(blob.data).cuda()#[torch.as_tensor(d).cuda() for d in blob.data]
        #print("this is the data size before permuting: {}".format(data.size()))
        data = data.permute(0,3,1,2)
        #print("this is the data size after permuting: {}".format(data.size()))
        prediction = blob.net(data)
        # Training
        loss,acc=-1,-1
        if blob.label is not None:
            label = torch.as_tensor(blob.label).type(torch.LongTensor).cuda()#[torch.as_tensor(l).cuda() for l in blob.label]
            label.requires_grad = False
            loss = blob.criterion(prediction,label)
        blob.loss = loss
        
        softmax    = blob.softmax(prediction).cpu().detach().numpy()
        prediction = torch.argmax(prediction,dim=-1)
        accuracy   = (prediction == label).sum().item() / float(prediction.nelement())        
        prediction = prediction.cpu().detach().numpy()
        
        return {'prediction' : prediction,
                'softmax'    : softmax,
                'loss'       : loss.cpu().detach().item(),
                'accuracy'   : accuracy}

def backward(blob):
    blob.optimizer.zero_grad()  # Reset gradients accumulation
    blob.loss.backward()
    blob.optimizer.step()

# %% [markdown]
# ## Running a train loop
# Let's prepare the data loaders for both train and test datasets. We use the latter to check if the network suffers from overtraining.

# %%
# Create data loader
from iotools import loader_factory
DATA_DIRS=['/data/hkml_data/IWCDgrid/varyE/e-','/data/hkml_data/IWCDgrid/varyE/mu-','/data/hkml_data/IWCDgrid/varyE/gamma']
# for train
train_loader=loader_factory('H5Dataset', batch_size=64, shuffle=True, num_workers=4, data_dirs=DATA_DIRS, flavour='1M.h5', start_fraction=0.0, use_fraction=0.8)
# for validation
val_loader=loader_factory('H5Dataset', batch_size=1000, shuffle=True, num_workers=2, data_dirs=DATA_DIRS, flavour='1M.h5', start_fraction=0.8, use_fraction=0.1)
# for final analysis
test_loader=loader_factory('H5Dataset', batch_size=1024, shuffle=True, num_workers=2, data_dirs=DATA_DIRS, flavour='1M.h5', start_fraction=0.9, use_fraction=0.1)
# Out:
# I found the following files: ['/data/hkml_data/IWCDgrid/varyE/e-/IWCDgrid_varyE_e-_R0cm_20-2000MeV_1M.h5', '/data/hkml_data/IWCDgrid/varyE/mu-/IWCDgrid_varyE_mu-_R0cm_20-2000MeV_1M.h5', '/data/hkml_data/IWCDgrid/varyE/gamma/IWCDgrid_varyE_gamma_R0cm_20-2000MeV_1M.h5']
# I found the following files: ['/data/hkml_data/IWCDgrid/varyE/e-/IWCDgrid_varyE_e-_R0cm_20-2000MeV_1M.h5', '/data/hkml_data/IWCDgrid/varyE/mu-/IWCDgrid_varyE_mu-_R0cm_20-2000MeV_1M.h5', '/data/hkml_data/IWCDgrid/varyE/gamma/IWCDgrid_varyE_gamma_R0cm_20-2000MeV_1M.h5']
# I found the following files: ['/data/hkml_data/IWCDgrid/varyE/e-/IWCDgrid_varyE_e-_R0cm_20-2000MeV_1M.h5', '/data/hkml_data/IWCDgrid/varyE/mu-/IWCDgrid_varyE_mu-_R0cm_20-2000MeV_1M.h5', '/data/hkml_data/IWCDgrid/varyE/gamma/IWCDgrid_varyE_gamma_R0cm_20-2000MeV_1M.h5']

# %% [markdown]
# Also import `CSVData` from our utility module, which lets us write train log (accuracy, loss, etc.) in a csv file.

# %%
# %rm log_train.csv log_val.csv

# %%
# Import 0) progress bar and 1) data recording utility (into csv file)
from utils import progress_bar, CSVData, disp_learn_hist, disp_train_smoothed

# %%
blob.train_log, blob.val_log = CSVData('log_train.csv'), CSVData('log_val.csv')

# %%
# !date
# Out:
# Wed Apr 17 06:38:48 UTC 2019

# %%
def save_state(blob, prefix='./snapshot'):
    # Output file name
    #filename = '%s-%d.ckpt' % (prefix, blob.iteration)
    filename = '%s.ckpt' % (prefix)
    
    # Save parameters
    # 0+1) iteration counter + optimizer state => in case we want to "continue training" later
    # 2) network weight
    torch.save({
        'global_step': blob.iteration,
        'optimizer': blob.optimizer.state_dict(),
        'state_dict': blob.net.state_dict()
        }, filename)
    return filename

def restore_state(weight_file, blob):
    # Open a file in read-binary mode
    with open(weight_file, 'rb') as f:
        # torch interprets the file, then we can access using string keys
        checkpoint = torch.load(f)
        # load network weights
        blob.net.load_state_dict(checkpoint['state_dict'], strict=False)
        # if optimizer is provided, load the state of the optimizer
        if blob.optimizer is not None:
            blob.optimizer.load_state_dict(checkpoint['optimizer'])
        # load iteration count
        blob.iteration = checkpoint['global_step']

# %% [markdown]
# Finally, we're ready to run the training! Let's create a dataloader, write a loop to  call forward and backward.

# %%
restore_state("snapshot-78600.ckpt",blob)

# %%
blob.iteration
blob.best_val_loss=0.289653033018

# %%
# Define train period. "epoch" = N image consumption where N is the total number of train samples.
TRAIN_EPOCH=30.0
# Set the network to training mode
blob.net.train()
if blob.iteration is not None and blob.iteration!=0:
    iteration=blob.iteration
    epoch=iteration/len(train_loader)
    best_val_loss=blob.best_val_loss
    print("re-starting")
else:
    epoch=0.
    iteration=0
    best_val_loss=1.0e6
    
# Start training


while int(epoch+0.5) < TRAIN_EPOCH:
    print('Epoch',int(epoch+0.5),'Starting @',time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()))
    # Create a progress bar for this epoch
    from utils import progress_bar
    progress = display(progress_bar(0,len(train_loader)),display_id=True)
    # Loop over data samples and into the network forward function
    for i,data in enumerate(train_loader):
        # Data and label
        blob.data,blob.label = data[0:2]
        
        
        #if i==0:
        #    print("the labels are:")
        #    print(blob.label)
        # Call forward: make a prediction & measure the average error
        res = forward(blob,True)
        # Call backward: backpropagate error and update weights
        backward(blob)
        # Epoch update
        epoch += 1./len(train_loader)
        iteration += 1
        blob.iteration=iteration
        #
        # Log/Report
        #
        # Record the current performance on train set
        blob.train_log.record(['iteration','epoch','accuracy','loss'],[iteration,epoch,res['accuracy'],res['loss']])
        blob.train_log.write()
        # once in a while, report
        if i==0 or (i+1)%10 == 0:
            message = '... Iteration %d ... Epoch %1.2f ... Loss %1.3f ... Accuracy %1.3f' % (iteration,epoch,res['loss'],res['accuracy'])
            progress.update(progress_bar((i+1),len(train_loader),message))
        # more rarely, run validation
        if (i+1)%100 == 0:
            with torch.no_grad():
                blob.net.eval()
                val_data = next(iter(val_loader))
                blob.data,blob.label = val_data[0:2]
                res = forward(blob,False)
                blob.val_log.record(['iteration','epoch','accuracy','loss'],[iteration,epoch,res['accuracy'],res['loss']])
                blob.val_log.write()
                blob.val_log.flush()
                print("VAL set results: iteration: {}, epoch: {}, accuracy: {}, loss: {}".format(iteration,epoch,res['accuracy'],res['loss']))
                save_state(blob)
                if res['loss']<best_val_loss:
                    print('best validation loss so far!')
                    best_val_loss=res['loss']
                    blob.best_val_loss=best_val_loss
                    save_state(blob,'./snapshot_best_{}'.format(blob.iteration))
                
                
            blob.net.train()
        if epoch >= TRAIN_EPOCH:
            break
    message = '... Iteration %d ... Epoch %1.2f ... Loss %1.3f ... Accuracy %1.3f' % (iteration,epoch,res['loss'],res['accuracy'])
    progress.update(progress_bar((i+1),len(train_loader),message))

blob.val_log.close()
blob.train_log.close()
# Out:
# re-starting
# Epoch 2 Starting @ 2019-04-17 08:24:38
#         <progress
#             value='33400'
#             max='37500',
#             style='width: 30%'
#         >
#             33400
#         </progress> 89% ... Iteration 112000 ... Epoch 2.89 ... Loss 0.314 ... Accuracy 0.844
# VAL set results: iteration: 78700, epoch: 2.00266666667, accuracy: 0.826, loss: 0.352070808411
# VAL set results: iteration: 78800, epoch: 2.00533333333, accuracy: 0.847, loss: 0.319704800844
# VAL set results: iteration: 78900, epoch: 2.008, accuracy: 0.836, loss: 0.340711265802
# VAL set results: iteration: 79000, epoch: 2.01066666667, accuracy: 0.848, loss: 0.325477063656
# VAL set results: iteration: 79100, epoch: 2.01333333333, accuracy: 0.851, loss: 0.320687234402
# VAL set results: iteration: 79200, epoch: 2.016, accuracy: 0.843, loss: 0.322315007448
# VAL set results: iteration: 79300, epoch: 2.01866666667, accuracy: 0.854, loss: 0.319491863251
# VAL set results: iteration: 79400, epoch: 2.02133333333, accuracy: 0.823, loss: 0.339656352997
# VAL set results: iteration: 79500, epoch: 2.024, accuracy: 0.851, loss: 0.326420903206
# VAL set results: iteration: 79600, epoch: 2.02666666667, accuracy: 0.855, loss: 0.295557051897
# VAL set results: iteration: 79700, epoch: 2.02933333333, accuracy: 0.845, loss: 0.32378295064
# VAL set results: iteration: 79800, epoch: 2.032, accuracy: 0.839, loss: 0.353259205818
# VAL set results: iteration: 79900, epoch: 2.03466666667, accuracy: 0.856, loss: 0.311176806688
# VAL set results: iteration: 80000, epoch: 2.03733333333, accuracy: 0.825, loss: 0.363782733679
# VAL set results: iteration: 80100, epoch: 2.04, accuracy: 0.85, loss: 0.328717261553
# VAL set results: iteration: 80200, epoch: 2.04266666667, accuracy: 0.872, loss: 0.287925690413
# best validation loss so far!
# VAL set results: iteration: 80300, epoch: 2.04533333333, accuracy: 0.841, loss: 0.334165424109
# VAL set results: iteration: 80400, epoch: 2.048, accuracy: 0.854, loss: 0.298549175262
# VAL set results: iteration: 80500, epoch: 2.05066666667, accuracy: 0.829, loss: 0.358699798584
# VAL set results: iteration: 80600, epoch: 2.05333333333, accuracy: 0.844, loss: 0.338849306107
# VAL set results: iteration: 80700, epoch: 2.056, accuracy: 0.856, loss: 0.307637602091
# VAL set results: iteration: 80800, epoch: 2.05866666667, accuracy: 0.834, loss: 0.342719495296
# VAL set results: iteration: 80900, epoch: 2.06133333333, accuracy: 0.854, loss: 0.324143111706
# VAL set results: iteration: 81000, epoch: 2.064, accuracy: 0.858, loss: 0.306742697954
# VAL set results: iteration: 81100, epoch: 2.06666666667, accuracy: 0.851, loss: 0.326408326626
# VAL set results: iteration: 81200, epoch: 2.06933333333, accuracy: 0.833, loss: 0.338747292757
# VAL set results: iteration: 81300, epoch: 2.072, accuracy: 0.821, loss: 0.365711241961
# VAL set results: iteration: 81400, epoch: 2.07466666667, accuracy: 0.854, loss: 0.308968752623
# VAL set results: iteration: 81500, epoch: 2.07733333333, accuracy: 0.843, loss: 0.333008259535
# VAL set results: iteration: 81600, epoch: 2.08, accuracy: 0.847, loss: 0.34530505538
# VAL set results: iteration: 81700, epoch: 2.08266666667, accuracy: 0.85, loss: 0.322689414024
# VAL set results: iteration: 81800, epoch: 2.08533333333, accuracy: 0.831, loss: 0.344278514385
# VAL set results: iteration: 81900, epoch: 2.088, accuracy: 0.837, loss: 0.357722818851
# VAL set results: iteration: 82000, epoch: 2.09066666667, accuracy: 0.837, loss: 0.345696181059
# VAL set results: iteration: 82100, epoch: 2.09333333333, accuracy: 0.837, loss: 0.32813501358
# VAL set results: iteration: 82200, epoch: 2.096, accuracy: 0.857, loss: 0.307111442089
# VAL set results: iteration: 82300, epoch: 2.09866666667, accuracy: 0.862, loss: 0.316321283579
# VAL set results: iteration: 82400, epoch: 2.10133333333, accuracy: 0.839, loss: 0.335150152445
# VAL set results: iteration: 82500, epoch: 2.104, accuracy: 0.859, loss: 0.315584540367
# VAL set results: iteration: 82600, epoch: 2.10666666667, accuracy: 0.838, loss: 0.344765514135
# VAL set results: iteration: 82700, epoch: 2.10933333333, accuracy: 0.844, loss: 0.3411257267
# VAL set results: iteration: 82800, epoch: 2.112, accuracy: 0.848, loss: 0.324763923883
# VAL set results: iteration: 82900, epoch: 2.11466666667, accuracy: 0.844, loss: 0.331056922674
# VAL set results: iteration: 83000, epoch: 2.11733333333, accuracy: 0.829, loss: 0.334674298763
# VAL set results: iteration: 83100, epoch: 2.12, accuracy: 0.836, loss: 0.339860647917
# VAL set results: iteration: 83200, epoch: 2.12266666667, accuracy: 0.853, loss: 0.316953718662
# VAL set results: iteration: 83300, epoch: 2.12533333333, accuracy: 0.819, loss: 0.386570572853
# VAL set results: iteration: 83400, epoch: 2.128, accuracy: 0.835, loss: 0.356407135725
# VAL set results: iteration: 83500, epoch: 2.13066666667, accuracy: 0.842, loss: 0.329458028078
# VAL set results: iteration: 83600, epoch: 2.13333333333, accuracy: 0.846, loss: 0.321832418442
# VAL set results: iteration: 83700, epoch: 2.136, accuracy: 0.85, loss: 0.313517391682
# VAL set results: iteration: 83800, epoch: 2.13866666667, accuracy: 0.837, loss: 0.340811312199
# VAL set results: iteration: 83900, epoch: 2.14133333333, accuracy: 0.853, loss: 0.320224702358
# VAL set results: iteration: 84000, epoch: 2.144, accuracy: 0.842, loss: 0.323891252279
# VAL set results: iteration: 84100, epoch: 2.14666666667, accuracy: 0.855, loss: 0.301804512739
# VAL set results: iteration: 84200, epoch: 2.14933333333, accuracy: 0.847, loss: 0.310519278049
# VAL set results: iteration: 84300, epoch: 2.152, accuracy: 0.825, loss: 0.346546083689
# VAL set results: iteration: 84400, epoch: 2.15466666667, accuracy: 0.83, loss: 0.350019216537
# VAL set results: iteration: 84500, epoch: 2.15733333333, accuracy: 0.855, loss: 0.311599045992
# VAL set results: iteration: 84600, epoch: 2.16, accuracy: 0.813, loss: 0.359156370163
# VAL set results: iteration: 84700, epoch: 2.16266666667, accuracy: 0.849, loss: 0.336680173874
# VAL set results: iteration: 84800, epoch: 2.16533333333, accuracy: 0.855, loss: 0.302810519934
# VAL set results: iteration: 84900, epoch: 2.168, accuracy: 0.855, loss: 0.318142175674
# VAL set results: iteration: 85000, epoch: 2.17066666667, accuracy: 0.842, loss: 0.330570101738
# VAL set results: iteration: 85100, epoch: 2.17333333333, accuracy: 0.816, loss: 0.376032352448
# VAL set results: iteration: 85200, epoch: 2.176, accuracy: 0.853, loss: 0.314949601889
# VAL set results: iteration: 85300, epoch: 2.17866666667, accuracy: 0.824, loss: 0.351397663355
# VAL set results: iteration: 85400, epoch: 2.18133333333, accuracy: 0.854, loss: 0.307779461145
# VAL set results: iteration: 85500, epoch: 2.184, accuracy: 0.84, loss: 0.325536370277
# VAL set results: iteration: 85600, epoch: 2.18666666667, accuracy: 0.867, loss: 0.293735206127
# VAL set results: iteration: 85700, epoch: 2.18933333333, accuracy: 0.849, loss: 0.33320081234
# VAL set results: iteration: 85800, epoch: 2.192, accuracy: 0.824, loss: 0.376520872116
# VAL set results: iteration: 85900, epoch: 2.19466666667, accuracy: 0.842, loss: 0.333476066589
# VAL set results: iteration: 86000, epoch: 2.19733333333, accuracy: 0.835, loss: 0.339164167643
# VAL set results: iteration: 86100, epoch: 2.2, accuracy: 0.849, loss: 0.330293923616
# VAL set results: iteration: 86200, epoch: 2.20266666667, accuracy: 0.857, loss: 0.326853126287
# VAL set results: iteration: 86300, epoch: 2.20533333333, accuracy: 0.85, loss: 0.318157464266
# VAL set results: iteration: 86400, epoch: 2.208, accuracy: 0.852, loss: 0.331285089254
# VAL set results: iteration: 86500, epoch: 2.21066666667, accuracy: 0.865, loss: 0.288152426481
# VAL set results: iteration: 86600, epoch: 2.21333333333, accuracy: 0.856, loss: 0.315590262413
# VAL set results: iteration: 86700, epoch: 2.216, accuracy: 0.822, loss: 0.353635340929
# VAL set results: iteration: 86800, epoch: 2.21866666667, accuracy: 0.831, loss: 0.349072098732
# VAL set results: iteration: 86900, epoch: 2.22133333333, accuracy: 0.829, loss: 0.361317694187
# VAL set results: iteration: 87000, epoch: 2.224, accuracy: 0.827, loss: 0.346503704786
# VAL set results: iteration: 87100, epoch: 2.22666666667, accuracy: 0.841, loss: 0.329634040594
# VAL set results: iteration: 87200, epoch: 2.22933333333, accuracy: 0.849, loss: 0.309526830912
# VAL set results: iteration: 87300, epoch: 2.232, accuracy: 0.828, loss: 0.363944917917
# VAL set results: iteration: 87400, epoch: 2.23466666667, accuracy: 0.855, loss: 0.317896664143
# VAL set results: iteration: 87500, epoch: 2.23733333333, accuracy: 0.846, loss: 0.33936047554
# VAL set results: iteration: 87600, epoch: 2.24, accuracy: 0.838, loss: 0.344420522451
# VAL set results: iteration: 87700, epoch: 2.24266666667, accuracy: 0.823, loss: 0.352201581001
# VAL set results: iteration: 87800, epoch: 2.24533333333, accuracy: 0.853, loss: 0.325289338827
# VAL set results: iteration: 87900, epoch: 2.248, accuracy: 0.851, loss: 0.314439892769
# VAL set results: iteration: 88000, epoch: 2.25066666667, accuracy: 0.845, loss: 0.320613026619
# VAL set results: iteration: 88100, epoch: 2.25333333333, accuracy: 0.862, loss: 0.297304570675
# VAL set results: iteration: 88200, epoch: 2.256, accuracy: 0.837, loss: 0.341936767101
# VAL set results: iteration: 88300, epoch: 2.25866666667, accuracy: 0.857, loss: 0.31075745821
# VAL set results: iteration: 88400, epoch: 2.26133333334, accuracy: 0.845, loss: 0.341497570276
# VAL set results: iteration: 88500, epoch: 2.264, accuracy: 0.839, loss: 0.339713603258
# VAL set results: iteration: 88600, epoch: 2.26666666667, accuracy: 0.845, loss: 0.325080573559
# VAL set results: iteration: 88700, epoch: 2.26933333334, accuracy: 0.84, loss: 0.336647361517
# VAL set results: iteration: 88800, epoch: 2.272, accuracy: 0.835, loss: 0.334197461605
# VAL set results: iteration: 88900, epoch: 2.27466666667, accuracy: 0.831, loss: 0.353773653507
# VAL set results: iteration: 89000, epoch: 2.27733333334, accuracy: 0.852, loss: 0.335987389088
# VAL set results: iteration: 89100, epoch: 2.28, accuracy: 0.853, loss: 0.329741209745
# VAL set results: iteration: 89200, epoch: 2.28266666667, accuracy: 0.831, loss: 0.344038337469
# VAL set results: iteration: 89300, epoch: 2.28533333334, accuracy: 0.854, loss: 0.326226711273
# VAL set results: iteration: 89400, epoch: 2.288, accuracy: 0.846, loss: 0.325830310583
# VAL set results: iteration: 89500, epoch: 2.29066666667, accuracy: 0.831, loss: 0.354351580143
# VAL set results: iteration: 89600, epoch: 2.29333333334, accuracy: 0.829, loss: 0.351757466793
# VAL set results: iteration: 89700, epoch: 2.296, accuracy: 0.841, loss: 0.34217569232
# VAL set results: iteration: 89800, epoch: 2.29866666667, accuracy: 0.848, loss: 0.320769935846
# VAL set results: iteration: 89900, epoch: 2.30133333334, accuracy: 0.853, loss: 0.308623045683
# VAL set results: iteration: 90000, epoch: 2.304, accuracy: 0.847, loss: 0.332883924246
# VAL set results: iteration: 90100, epoch: 2.30666666667, accuracy: 0.849, loss: 0.324395447969
# VAL set results: iteration: 90200, epoch: 2.30933333334, accuracy: 0.837, loss: 0.337873846292
# VAL set results: iteration: 90300, epoch: 2.312, accuracy: 0.859, loss: 0.312939286232
# VAL set results: iteration: 90400, epoch: 2.31466666667, accuracy: 0.856, loss: 0.313177764416
# VAL set results: iteration: 90500, epoch: 2.31733333334, accuracy: 0.828, loss: 0.339946895838
# VAL set results: iteration: 90600, epoch: 2.32, accuracy: 0.842, loss: 0.341287255287
# VAL set results: iteration: 90700, epoch: 2.32266666667, accuracy: 0.851, loss: 0.326026201248
# VAL set results: iteration: 90800, epoch: 2.32533333334, accuracy: 0.845, loss: 0.311728090048
# VAL set results: iteration: 90900, epoch: 2.328, accuracy: 0.848, loss: 0.331459730864
# VAL set results: iteration: 91000, epoch: 2.33066666667, accuracy: 0.83, loss: 0.353406608105
# VAL set results: iteration: 91100, epoch: 2.33333333334, accuracy: 0.834, loss: 0.341661721468
# VAL set results: iteration: 91200, epoch: 2.336, accuracy: 0.822, loss: 0.371383965015
# VAL set results: iteration: 91300, epoch: 2.33866666667, accuracy: 0.84, loss: 0.34334230423
# VAL set results: iteration: 91400, epoch: 2.34133333334, accuracy: 0.828, loss: 0.357127249241
# VAL set results: iteration: 91500, epoch: 2.344, accuracy: 0.832, loss: 0.348324000835
# VAL set results: iteration: 91600, epoch: 2.34666666667, accuracy: 0.838, loss: 0.334601640701
# VAL set results: iteration: 91700, epoch: 2.34933333334, accuracy: 0.853, loss: 0.32306560874
# VAL set results: iteration: 91800, epoch: 2.352, accuracy: 0.842, loss: 0.331505507231
# VAL set results: iteration: 91900, epoch: 2.35466666667, accuracy: 0.844, loss: 0.332501173019
# VAL set results: iteration: 92000, epoch: 2.35733333334, accuracy: 0.841, loss: 0.333916693926
# VAL set results: iteration: 92100, epoch: 2.36, accuracy: 0.846, loss: 0.308522433043
# VAL set results: iteration: 92200, epoch: 2.36266666667, accuracy: 0.84, loss: 0.326916158199
# VAL set results: iteration: 92300, epoch: 2.36533333334, accuracy: 0.821, loss: 0.370458334684
# VAL set results: iteration: 92400, epoch: 2.368, accuracy: 0.83, loss: 0.353261232376
# VAL set results: iteration: 92500, epoch: 2.37066666667, accuracy: 0.856, loss: 0.305485218763
# VAL set results: iteration: 92600, epoch: 2.37333333334, accuracy: 0.856, loss: 0.326690971851
# VAL set results: iteration: 92700, epoch: 2.376, accuracy: 0.843, loss: 0.328242152929
# VAL set results: iteration: 92800, epoch: 2.37866666667, accuracy: 0.833, loss: 0.356777995825
# VAL set results: iteration: 92900, epoch: 2.38133333334, accuracy: 0.85, loss: 0.320686221123
# VAL set results: iteration: 93000, epoch: 2.384, accuracy: 0.825, loss: 0.343833386898
# VAL set results: iteration: 93100, epoch: 2.38666666667, accuracy: 0.841, loss: 0.321284770966
# VAL set results: iteration: 93200, epoch: 2.38933333334, accuracy: 0.851, loss: 0.319282889366
# VAL set results: iteration: 93300, epoch: 2.392, accuracy: 0.854, loss: 0.320895701647
# VAL set results: iteration: 93400, epoch: 2.39466666667, accuracy: 0.855, loss: 0.332902342081
# VAL set results: iteration: 93500, epoch: 2.39733333334, accuracy: 0.828, loss: 0.338746249676
# VAL set results: iteration: 93600, epoch: 2.4, accuracy: 0.826, loss: 0.34871762991
# VAL set results: iteration: 93700, epoch: 2.40266666667, accuracy: 0.849, loss: 0.324665904045
# VAL set results: iteration: 93800, epoch: 2.40533333334, accuracy: 0.839, loss: 0.34965223074
# VAL set results: iteration: 93900, epoch: 2.408, accuracy: 0.849, loss: 0.318894922733
# VAL set results: iteration: 94000, epoch: 2.41066666667, accuracy: 0.855, loss: 0.299103945494
# VAL set results: iteration: 94100, epoch: 2.41333333334, accuracy: 0.849, loss: 0.324970364571
# VAL set results: iteration: 94200, epoch: 2.416, accuracy: 0.844, loss: 0.334755301476
# VAL set results: iteration: 94300, epoch: 2.41866666667, accuracy: 0.83, loss: 0.362868696451
# VAL set results: iteration: 94400, epoch: 2.42133333334, accuracy: 0.813, loss: 0.378790199757
# VAL set results: iteration: 94500, epoch: 2.424, accuracy: 0.84, loss: 0.357561677694
# VAL set results: iteration: 94600, epoch: 2.42666666667, accuracy: 0.849, loss: 0.330138325691
# VAL set results: iteration: 94700, epoch: 2.42933333334, accuracy: 0.841, loss: 0.348862081766
# VAL set results: iteration: 94800, epoch: 2.432, accuracy: 0.856, loss: 0.321775794029
# VAL set results: iteration: 94900, epoch: 2.43466666667, accuracy: 0.841, loss: 0.33224567771
# VAL set results: iteration: 95000, epoch: 2.43733333334, accuracy: 0.85, loss: 0.315576165915
# VAL set results: iteration: 95100, epoch: 2.44, accuracy: 0.824, loss: 0.363360106945
# VAL set results: iteration: 95200, epoch: 2.44266666667, accuracy: 0.843, loss: 0.336488753557
# VAL set results: iteration: 95300, epoch: 2.44533333334, accuracy: 0.855, loss: 0.332240402699
# VAL set results: iteration: 95400, epoch: 2.448, accuracy: 0.843, loss: 0.317730396986
# VAL set results: iteration: 95500, epoch: 2.45066666667, accuracy: 0.836, loss: 0.33717995882
# VAL set results: iteration: 95600, epoch: 2.45333333334, accuracy: 0.855, loss: 0.311766088009
# VAL set results: iteration: 95700, epoch: 2.456, accuracy: 0.832, loss: 0.34473836422
# VAL set results: iteration: 95800, epoch: 2.45866666667, accuracy: 0.833, loss: 0.345501869917
# VAL set results: iteration: 95900, epoch: 2.46133333334, accuracy: 0.833, loss: 0.340579092503
# VAL set results: iteration: 96000, epoch: 2.464, accuracy: 0.824, loss: 0.34378683567
# VAL set results: iteration: 96100, epoch: 2.46666666667, accuracy: 0.84, loss: 0.346521258354
# VAL set results: iteration: 96200, epoch: 2.46933333334, accuracy: 0.834, loss: 0.337419748306
# VAL set results: iteration: 96300, epoch: 2.472, accuracy: 0.862, loss: 0.313805311918
# VAL set results: iteration: 96400, epoch: 2.47466666667, accuracy: 0.854, loss: 0.314068228006
# VAL set results: iteration: 96500, epoch: 2.47733333334, accuracy: 0.852, loss: 0.340545415878
# VAL set results: iteration: 96600, epoch: 2.48, accuracy: 0.854, loss: 0.329252928495
# VAL set results: iteration: 96700, epoch: 2.48266666667, accuracy: 0.855, loss: 0.300931215286
# VAL set results: iteration: 96800, epoch: 2.48533333334, accuracy: 0.845, loss: 0.32695132494
# VAL set results: iteration: 96900, epoch: 2.488, accuracy: 0.835, loss: 0.370348960161
# VAL set results: iteration: 97000, epoch: 2.49066666667, accuracy: 0.824, loss: 0.351773411036
# VAL set results: iteration: 97100, epoch: 2.49333333334, accuracy: 0.85, loss: 0.334495991468
# VAL set results: iteration: 97200, epoch: 2.496, accuracy: 0.826, loss: 0.344449579716
# VAL set results: iteration: 97300, epoch: 2.49866666667, accuracy: 0.846, loss: 0.330296069384
# VAL set results: iteration: 97400, epoch: 2.50133333334, accuracy: 0.856, loss: 0.332021832466
# VAL set results: iteration: 97500, epoch: 2.504, accuracy: 0.86, loss: 0.314558804035
# VAL set results: iteration: 97600, epoch: 2.50666666667, accuracy: 0.856, loss: 0.32083144784
# VAL set results: iteration: 97700, epoch: 2.50933333334, accuracy: 0.85, loss: 0.309797167778
# VAL set results: iteration: 97800, epoch: 2.512, accuracy: 0.849, loss: 0.325689762831
# VAL set results: iteration: 97900, epoch: 2.51466666667, accuracy: 0.826, loss: 0.353296071291
# VAL set results: iteration: 98000, epoch: 2.51733333334, accuracy: 0.843, loss: 0.340776354074
# VAL set results: iteration: 98100, epoch: 2.52, accuracy: 0.854, loss: 0.312164872885
# VAL set results: iteration: 98200, epoch: 2.52266666667, accuracy: 0.847, loss: 0.33605670929
# VAL set results: iteration: 98300, epoch: 2.52533333334, accuracy: 0.85, loss: 0.319878220558
# VAL set results: iteration: 98400, epoch: 2.528, accuracy: 0.835, loss: 0.34120708704
# VAL set results: iteration: 98500, epoch: 2.53066666667, accuracy: 0.835, loss: 0.33047118783
# VAL set results: iteration: 98600, epoch: 2.53333333334, accuracy: 0.821, loss: 0.341112822294
# VAL set results: iteration: 98700, epoch: 2.536, accuracy: 0.851, loss: 0.321104109287
# VAL set results: iteration: 98800, epoch: 2.53866666667, accuracy: 0.818, loss: 0.374228566885
# VAL set results: iteration: 98900, epoch: 2.54133333334, accuracy: 0.878, loss: 0.292542904615
# VAL set results: iteration: 99000, epoch: 2.544, accuracy: 0.863, loss: 0.32272490859
# VAL set results: iteration: 99100, epoch: 2.54666666667, accuracy: 0.868, loss: 0.303780436516
# VAL set results: iteration: 99200, epoch: 2.54933333334, accuracy: 0.835, loss: 0.356621146202
# VAL set results: iteration: 99300, epoch: 2.552, accuracy: 0.846, loss: 0.322582662106
# VAL set results: iteration: 99400, epoch: 2.55466666667, accuracy: 0.868, loss: 0.315305382013
# VAL set results: iteration: 99500, epoch: 2.55733333334, accuracy: 0.831, loss: 0.336679637432
# VAL set results: iteration: 99600, epoch: 2.56, accuracy: 0.821, loss: 0.353582084179
# VAL set results: iteration: 99700, epoch: 2.56266666667, accuracy: 0.835, loss: 0.357550233603
# VAL set results: iteration: 99800, epoch: 2.56533333334, accuracy: 0.844, loss: 0.324621796608
# VAL set results: iteration: 99900, epoch: 2.568, accuracy: 0.855, loss: 0.315169215202
# VAL set results: iteration: 100000, epoch: 2.57066666667, accuracy: 0.856, loss: 0.319056898355
# VAL set results: iteration: 100100, epoch: 2.57333333334, accuracy: 0.87, loss: 0.301667869091
# VAL set results: iteration: 100200, epoch: 2.576, accuracy: 0.826, loss: 0.349980324507
# VAL set results: iteration: 100300, epoch: 2.57866666667, accuracy: 0.848, loss: 0.34554028511
# VAL set results: iteration: 100400, epoch: 2.58133333334, accuracy: 0.853, loss: 0.321733623743
# VAL set results: iteration: 100500, epoch: 2.584, accuracy: 0.847, loss: 0.328552305698
# VAL set results: iteration: 100600, epoch: 2.58666666667, accuracy: 0.843, loss: 0.335452586412
# VAL set results: iteration: 100700, epoch: 2.58933333334, accuracy: 0.833, loss: 0.345286428928
# VAL set results: iteration: 100800, epoch: 2.592, accuracy: 0.852, loss: 0.318102449179
# VAL set results: iteration: 100900, epoch: 2.59466666667, accuracy: 0.856, loss: 0.309055268764
# VAL set results: iteration: 101000, epoch: 2.59733333334, accuracy: 0.86, loss: 0.317660421133
# VAL set results: iteration: 101100, epoch: 2.6, accuracy: 0.847, loss: 0.315435230732
# VAL set results: iteration: 101200, epoch: 2.60266666667, accuracy: 0.84, loss: 0.338827252388
# VAL set results: iteration: 101300, epoch: 2.60533333334, accuracy: 0.839, loss: 0.34542915225
# VAL set results: iteration: 101400, epoch: 2.608, accuracy: 0.849, loss: 0.331190288067
# VAL set results: iteration: 101500, epoch: 2.61066666667, accuracy: 0.852, loss: 0.332089990377
# VAL set results: iteration: 101600, epoch: 2.61333333334, accuracy: 0.822, loss: 0.360150128603
# VAL set results: iteration: 101700, epoch: 2.616, accuracy: 0.853, loss: 0.323725253344
# VAL set results: iteration: 101800, epoch: 2.61866666667, accuracy: 0.832, loss: 0.363446414471
# VAL set results: iteration: 101900, epoch: 2.62133333334, accuracy: 0.829, loss: 0.331094175577
# VAL set results: iteration: 102000, epoch: 2.624, accuracy: 0.834, loss: 0.339015066624
# VAL set results: iteration: 102100, epoch: 2.62666666667, accuracy: 0.858, loss: 0.308795630932
# VAL set results: iteration: 102200, epoch: 2.62933333334, accuracy: 0.84, loss: 0.339810848236
# VAL set results: iteration: 102300, epoch: 2.632, accuracy: 0.869, loss: 0.301854908466
# VAL set results: iteration: 102400, epoch: 2.63466666667, accuracy: 0.857, loss: 0.313907891512
# VAL set results: iteration: 102500, epoch: 2.63733333334, accuracy: 0.858, loss: 0.302225470543
# VAL set results: iteration: 102600, epoch: 2.64, accuracy: 0.855, loss: 0.32917457819
# VAL set results: iteration: 102700, epoch: 2.64266666667, accuracy: 0.835, loss: 0.364610642195
# VAL set results: iteration: 102800, epoch: 2.64533333334, accuracy: 0.842, loss: 0.340013116598
# VAL set results: iteration: 102900, epoch: 2.648, accuracy: 0.85, loss: 0.322379916906
# VAL set results: iteration: 103000, epoch: 2.65066666667, accuracy: 0.847, loss: 0.329081326723
# VAL set results: iteration: 103100, epoch: 2.65333333334, accuracy: 0.854, loss: 0.329905986786
# VAL set results: iteration: 103200, epoch: 2.656, accuracy: 0.848, loss: 0.332245409489
# VAL set results: iteration: 103300, epoch: 2.65866666667, accuracy: 0.863, loss: 0.308278977871
# VAL set results: iteration: 103400, epoch: 2.66133333334, accuracy: 0.833, loss: 0.356792420149
# VAL set results: iteration: 103500, epoch: 2.664, accuracy: 0.854, loss: 0.345607876778
# VAL set results: iteration: 103600, epoch: 2.66666666667, accuracy: 0.82, loss: 0.386075764894
# VAL set results: iteration: 103700, epoch: 2.66933333334, accuracy: 0.838, loss: 0.347139269114
# VAL set results: iteration: 103800, epoch: 2.672, accuracy: 0.842, loss: 0.317277282476
# VAL set results: iteration: 103900, epoch: 2.67466666667, accuracy: 0.852, loss: 0.33780798316
# VAL set results: iteration: 104000, epoch: 2.67733333334, accuracy: 0.832, loss: 0.359083682299
# VAL set results: iteration: 104100, epoch: 2.68, accuracy: 0.811, loss: 0.377055883408
# VAL set results: iteration: 104200, epoch: 2.68266666667, accuracy: 0.831, loss: 0.355182766914
# VAL set results: iteration: 104300, epoch: 2.68533333334, accuracy: 0.844, loss: 0.332495212555
# VAL set results: iteration: 104400, epoch: 2.688, accuracy: 0.835, loss: 0.359837293625
# VAL set results: iteration: 104500, epoch: 2.69066666667, accuracy: 0.835, loss: 0.329180061817
# VAL set results: iteration: 104600, epoch: 2.69333333334, accuracy: 0.842, loss: 0.350561887026
# VAL set results: iteration: 104700, epoch: 2.696, accuracy: 0.826, loss: 0.358832806349
# VAL set results: iteration: 104800, epoch: 2.69866666667, accuracy: 0.842, loss: 0.329740703106
# VAL set results: iteration: 104900, epoch: 2.70133333334, accuracy: 0.869, loss: 0.294894605875
# VAL set results: iteration: 105000, epoch: 2.704, accuracy: 0.841, loss: 0.348348975182
# VAL set results: iteration: 105100, epoch: 2.70666666667, accuracy: 0.82, loss: 0.354078710079
# VAL set results: iteration: 105200, epoch: 2.70933333334, accuracy: 0.835, loss: 0.340669304132
# VAL set results: iteration: 105300, epoch: 2.712, accuracy: 0.849, loss: 0.354135930538
# VAL set results: iteration: 105400, epoch: 2.71466666667, accuracy: 0.855, loss: 0.321316480637
# VAL set results: iteration: 105500, epoch: 2.71733333334, accuracy: 0.855, loss: 0.314788013697
# VAL set results: iteration: 105600, epoch: 2.72, accuracy: 0.859, loss: 0.324904412031
# VAL set results: iteration: 105700, epoch: 2.72266666667, accuracy: 0.829, loss: 0.349460333586
# VAL set results: iteration: 105800, epoch: 2.72533333334, accuracy: 0.837, loss: 0.333981245756
# VAL set results: iteration: 105900, epoch: 2.728, accuracy: 0.829, loss: 0.350466042757
# VAL set results: iteration: 106000, epoch: 2.73066666667, accuracy: 0.863, loss: 0.310252904892
# VAL set results: iteration: 106100, epoch: 2.73333333334, accuracy: 0.81, loss: 0.366296052933
# VAL set results: iteration: 106200, epoch: 2.736, accuracy: 0.838, loss: 0.327443242073
# VAL set results: iteration: 106300, epoch: 2.73866666667, accuracy: 0.837, loss: 0.344796806574
# VAL set results: iteration: 106400, epoch: 2.74133333334, accuracy: 0.853, loss: 0.320406168699
# VAL set results: iteration: 106500, epoch: 2.744, accuracy: 0.843, loss: 0.328569859266
# VAL set results: iteration: 106600, epoch: 2.74666666667, accuracy: 0.867, loss: 0.306275755167
# VAL set results: iteration: 106700, epoch: 2.74933333334, accuracy: 0.842, loss: 0.339312583208
# VAL set results: iteration: 106800, epoch: 2.752, accuracy: 0.855, loss: 0.294224768877
# VAL set results: iteration: 106900, epoch: 2.75466666667, accuracy: 0.831, loss: 0.349332660437
# VAL set results: iteration: 107000, epoch: 2.75733333334, accuracy: 0.835, loss: 0.349226206541
# VAL set results: iteration: 107100, epoch: 2.76, accuracy: 0.829, loss: 0.351269364357
# VAL set results: iteration: 107200, epoch: 2.76266666667, accuracy: 0.848, loss: 0.324326843023
# VAL set results: iteration: 107300, epoch: 2.76533333334, accuracy: 0.851, loss: 0.325736314058
# VAL set results: iteration: 107400, epoch: 2.76800000001, accuracy: 0.839, loss: 0.343798190355
# VAL set results: iteration: 107500, epoch: 2.77066666667, accuracy: 0.827, loss: 0.365708649158
# VAL set results: iteration: 107600, epoch: 2.77333333334, accuracy: 0.845, loss: 0.330530405045
# VAL set results: iteration: 107700, epoch: 2.77600000001, accuracy: 0.836, loss: 0.346222430468
# VAL set results: iteration: 107800, epoch: 2.77866666667, accuracy: 0.865, loss: 0.315087229013
# VAL set results: iteration: 107900, epoch: 2.78133333334, accuracy: 0.817, loss: 0.372870385647
# VAL set results: iteration: 108000, epoch: 2.78400000001, accuracy: 0.807, loss: 0.414392799139
# VAL set results: iteration: 108100, epoch: 2.78666666667, accuracy: 0.85, loss: 0.321538150311
# VAL set results: iteration: 108200, epoch: 2.78933333334, accuracy: 0.842, loss: 0.33645761013
# VAL set results: iteration: 108300, epoch: 2.79200000001, accuracy: 0.813, loss: 0.362483143806
# VAL set results: iteration: 108400, epoch: 2.79466666667, accuracy: 0.854, loss: 0.297641962767
# VAL set results: iteration: 108500, epoch: 2.79733333334, accuracy: 0.858, loss: 0.322337657213
# VAL set results: iteration: 108600, epoch: 2.80000000001, accuracy: 0.843, loss: 0.335251450539
# VAL set results: iteration: 108700, epoch: 2.80266666667, accuracy: 0.851, loss: 0.333552598953
# VAL set results: iteration: 108800, epoch: 2.80533333334, accuracy: 0.833, loss: 0.340208351612
# VAL set results: iteration: 108900, epoch: 2.80800000001, accuracy: 0.831, loss: 0.344451069832
# VAL set results: iteration: 109000, epoch: 2.81066666667, accuracy: 0.836, loss: 0.336739629507
# VAL set results: iteration: 109100, epoch: 2.81333333334, accuracy: 0.86, loss: 0.311357289553
# VAL set results: iteration: 109200, epoch: 2.81600000001, accuracy: 0.843, loss: 0.333507984877
# VAL set results: iteration: 109300, epoch: 2.81866666667, accuracy: 0.858, loss: 0.308767676353
# VAL set results: iteration: 109400, epoch: 2.82133333334, accuracy: 0.83, loss: 0.341836869717
# VAL set results: iteration: 109500, epoch: 2.82400000001, accuracy: 0.84, loss: 0.321508169174
# VAL set results: iteration: 109600, epoch: 2.82666666667, accuracy: 0.825, loss: 0.352882504463
# VAL set results: iteration: 109700, epoch: 2.82933333334, accuracy: 0.835, loss: 0.349987626076
# VAL set results: iteration: 109800, epoch: 2.83200000001, accuracy: 0.833, loss: 0.349222332239
# VAL set results: iteration: 109900, epoch: 2.83466666667, accuracy: 0.859, loss: 0.300156235695
# VAL set results: iteration: 110000, epoch: 2.83733333334, accuracy: 0.845, loss: 0.302869051695
# VAL set results: iteration: 110100, epoch: 2.84000000001, accuracy: 0.85, loss: 0.325055807829
# VAL set results: iteration: 110200, epoch: 2.84266666667, accuracy: 0.811, loss: 0.375599384308
# VAL set results: iteration: 110300, epoch: 2.84533333334, accuracy: 0.818, loss: 0.349031209946
# VAL set results: iteration: 110400, epoch: 2.84800000001, accuracy: 0.863, loss: 0.317417651415
# VAL set results: iteration: 110500, epoch: 2.85066666667, accuracy: 0.83, loss: 0.348945736885
# VAL set results: iteration: 110600, epoch: 2.85333333334, accuracy: 0.843, loss: 0.324381440878
# VAL set results: iteration: 110700, epoch: 2.85600000001, accuracy: 0.825, loss: 0.364691197872
# VAL set results: iteration: 110800, epoch: 2.85866666667, accuracy: 0.843, loss: 0.318329185247
# VAL set results: iteration: 110900, epoch: 2.86133333334, accuracy: 0.832, loss: 0.347442895174
# VAL set results: iteration: 111000, epoch: 2.86400000001, accuracy: 0.835, loss: 0.344972223043
# VAL set results: iteration: 111100, epoch: 2.86666666667, accuracy: 0.858, loss: 0.300298780203
# VAL set results: iteration: 111200, epoch: 2.86933333334, accuracy: 0.869, loss: 0.301334887743
# VAL set results: iteration: 111300, epoch: 2.87200000001, accuracy: 0.837, loss: 0.333753794432
# VAL set results: iteration: 111400, epoch: 2.87466666667, accuracy: 0.859, loss: 0.318095088005
# VAL set results: iteration: 111500, epoch: 2.87733333334, accuracy: 0.838, loss: 0.341658711433
# VAL set results: iteration: 111600, epoch: 2.88000000001, accuracy: 0.836, loss: 0.342532604933
# VAL set results: iteration: 111700, epoch: 2.88266666667, accuracy: 0.821, loss: 0.348343133926
# VAL set results: iteration: 111800, epoch: 2.88533333334, accuracy: 0.842, loss: 0.334745287895
# VAL set results: iteration: 111900, epoch: 2.88800000001, accuracy: 0.849, loss: 0.319928616285
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-27-c0c8c8a9aae0> in <module>()
#      52             with torch.no_grad():
#      53                 blob.net.eval()
# ---> 54                 val_data = next(iter(val_loader))
#      55                 blob.data,blob.label = val_data[0:2]
#      56                 res = forward(blob,False)
#
# /usr/local/lib/python2.7/dist-packages/torch/utils/data/dataloader.pyc in __iter__(self)
#     817
#     818     def __iter__(self):
# --> 819         return _DataLoaderIter(self)
#     820
#     821     def __len__(self):
#
# /usr/local/lib/python2.7/dist-packages/torch/utils/data/dataloader.pyc in __init__(self, loader)
#     558                 #     before it starts, and __del__ tries to join but will get:
#     559                 #     AssertionError: can only join a started process.
# --> 560                 w.start()
#     561                 self.index_queues.append(index_queue)
#     562                 self.workers.append(w)
#
# /usr/lib/python2.7/multiprocessing/process.pyc in start(self)
#     128         else:
#     129             from .forking import Popen
# --> 130         self._popen = Popen(self)
#     131         _current_process._children.add(self)
#     132
#
# /usr/lib/python2.7/multiprocessing/forking.pyc in __init__(self, process_obj)
#     119             self.returncode = None
#     120
# --> 121             self.pid = os.fork()
#     122             if self.pid == 0:
#     123                 if 'random' in sys.modules:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Inspecting the training process
# Let's plot the train log for both train and test set.

# %%
disp_learn_hist(blob.train_log, blob.val_log)

# %% [markdown]
# We see the loss is coming down while the accuracy is increasing. These two should be anti-correlated, so this is expected. We also see the network performance on the test dataset (circles) follow those of train dataset (lines). This means there is no apparent overtraining.
#
# **Question: is the network still learning?**
# Both the loss and accuracy curve have large fluctuations and it is somewhat hard to see if the values are still changing. Let's plot the moving average of the loss and accuracy values.

# %%
disp_train_smoothed(blob.train_log, blob.val_log)

# %% [markdown]
# The tick lines now represent the moving average (all data points are from the train log). It appears the network is still learning. We can train for a longer period to achieve a better accuracy.
#
# ## Performance Analysis
# Beyond looking at the performance of the network, we can analyze how the network is performing for each classification target. Let's first obtain a high-statistics analysis output by running the network on all test samples.
#
# First load the stored model

# %%
restore_state("snapshots_1M_densenet_BS64/snapshot_best_80200.ckpt",blob)

# %%
# blob.data,blob.label = next(iter(test_loader))[0:2]

# %%
# res=forward(blob,False)

# %%
def inference(blob,data_loader):
    label,prediction,accuracy=[],[],[]
    # set the network to test (non-train) mode
    blob.net.eval()
    # create the result holder
    index,label,prediction = [],[],[]
    for i,data in enumerate(data_loader):
        if i%10==0:
            print("iteration {}".format(i))
        blob.data, blob.label = data[0:2]
        res = forward(blob,False)
        accuracy.append(res['accuracy'])
        prediction.append(res['prediction'])
        label.append(blob.label)
        #if i==2: break
    # report accuracy
    accuracy   = np.array(accuracy,dtype=np.float32)
    label      = np.hstack(label)
    prediction = np.hstack(prediction)
    
    return accuracy, label, prediction

# %% [markdown]
# Let's run the inference using this function on the test sample, and look at the error matrix.

# %%
from utils import plot_confusion_matrix
accuracy,label,prediction = inference(blob,test_loader)
print('Accuracy mean',accuracy.mean(),'std',accuracy.std())
plot_confusion_matrix(label,prediction,['gamma','electron','muon'])
# Out:
# iteration 0
# iteration 10
# iteration 20
# iteration 30
# iteration 40
# iteration 50
# iteration 60
# iteration 70
# iteration 80
# iteration 90
# iteration 100
# iteration 110
# iteration 120
# iteration 130
# iteration 140
# iteration 150
# iteration 160
# iteration 170
# iteration 180
# iteration 190
# iteration 200
# iteration 210
# iteration 220
# iteration 230
# iteration 240
# iteration 250
# iteration 260
# iteration 270
# iteration 280
# iteration 290
# Accuracy mean 0.84228945 std 0.011501167

# %% [markdown]
# As one may expect, muon is distinguished fairly well while there is some confusion between electron and gamma ray.
